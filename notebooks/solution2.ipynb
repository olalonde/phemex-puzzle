# %%
from ipynb.fs.full.utils import test_num, mega_string_perms
from itertools import permutations, combinations, product
from hashlib import sha256
from functools import reduce

# %%
strings = ['ETH', 'BTC', 'XRP', 'Phemex', '957496696762772407663']

# %%
prime21 = 957496696762772407663

# %%
def hash(str):
    h = sha256(str.encode()).hexdigest()
    return int(h, 16)
hash('test')
# Out:
# 72155939486846849509759369733266486982821795810448245423168957390607644363272

# %%
strings_lst = mega_string_perms(strings)

# %%
seps = ['', '-', '#', '+', '/', ',', '.', '@', '=', '!']
for strings in strings_lst:
    for sep in seps:
        word = sep.join(strings)
        print(word)
        h = hash(word)
        test_num(h)
        test_num(h + prime21)
        test_num(h * prime21)
        test_num(h ^ prime21)
# Out:
# ETH
# ETH
# ETH
# ETH
# ETH
# ETH
# ETH
# ETH
# ETH
# ETH
# BTC
# BTC
# BTC
# BTC
# BTC
# BTC
# BTC
# BTC
# BTC
# BTC
# XRP
# XRP
# XRP
# XRP
# XRP
# XRP
# XRP
# XRP
# XRP
# XRP
# Phemex
# Phemex
# Phemex
# Phemex
# Phemex
# Phemex
# Phemex
# Phemex
# Phemex
# Phemex
# 957496696762772407663
# 957496696762772407663
# 957496696762772407663
# 957496696762772407663
# 957496696762772407663
# 957496696762772407663
# 957496696762772407663
# 957496696762772407663
# 957496696762772407663
# 957496696762772407663
# ETHBTC
# ETH-BTC
# ETH#BTC
# ETH+BTC
# ETH/BTC
# ETH,BTC
# ETH.BTC
# ETH@BTC
# ETH=BTC
# ETH!BTC
# ETHXRP
# ETH-XRP
# ETH#XRP
# ETH+XRP
# ETH/XRP
# ETH,XRP
# ETH.XRP
# ETH@XRP
# ETH=XRP
# ETH!XRP
# ETHPhemex
# ETH-Phemex
# ETH#Phemex
# ETH+Phemex
# ETH/Phemex
# ETH,Phemex
# ETH.Phemex
# ETH@Phemex
# ETH=Phemex
# ETH!Phemex
# ETH957496696762772407663
# ETH-957496696762772407663
# ETH#957496696762772407663
# ETH+957496696762772407663
# ETH/957496696762772407663
# ...

# %%
# nope
